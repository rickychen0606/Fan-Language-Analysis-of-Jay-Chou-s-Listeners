# %%
pip install google-api-python-client python-dotenv pandas
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (2.171.0)
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (2.38.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (2.25.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (4.2.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2025.4.26)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.0

# %%
# jay_youtube_scraper.py
import os
import time
import pandas as pd
from dotenv import load_dotenv
from googleapiclient.discovery import build

# 讀取 API 金鑰
load_dotenv()
API_KEY = os.getenv("YOUTUBE_API_KEY")
youtube = build("youtube", "v3", developerKey=API_KEY)

# 取得播放清單中的所有影片
def get_videos_from_playlist(playlist_id):
    videos = []
    next_page_token = None

    while True:
        request = youtube.playlistItems().list(
            part="snippet",
            playlistId=playlist_id,
            maxResults=50,
            pageToken=next_page_token
        )
        response = request.execute()

        for item in response["items"]:
            snippet = item["snippet"]
            video_id = snippet["resourceId"]["videoId"]
            title = snippet["title"]
            videos.append({
                "video_id": video_id,
                "title": title
            })

        next_page_token = response.get("nextPageToken")
        if not next_page_token:
            break

    return pd.DataFrame(videos)

# 抓每部影片的留言
def get_comments(video_id, max_results=500):
    comments = []
    next_page_token = None
    count = 0

    while True:
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100,
            pageToken=next_page_token,
            textFormat="plainText"
        )
        response = request.execute()

        for item in response["items"]:
            comment = item["snippet"]["topLevelComment"]["snippet"]
            comments.append({
                "video_id": video_id,
                "author": comment.get("authorDisplayName"),
                "text": comment.get("textDisplay"),
                "published_at": comment.get("publishedAt")
            })
            count += 1
            if count >= max_results:
                break

        next_page_token = response.get("nextPageToken")
        if not next_page_token or count >= max_results:
            break

        time.sleep(0.5)

    return pd.DataFrame(comments)

# 主流程：先抓清單 → 再批次抓留言
def scrape_jay_playlist(playlist_id, max_per_video=500, output_path="jay_playlist_comments.csv"):
    print("📥 抓取播放清單影片中...")
    video_df = get_videos_from_playlist(playlist_id)
    print(f"✅ 共找到 {len(video_df)} 部影片")

    all_comments = []

    for i, row in video_df.iterrows():
        vid = row["video_id"]
        title = row["title"]
        print(f"🎬 處理中：{title} ({vid})")

        try:
            df_comments = get_comments(vid, max_results=max_per_video)
            df_comments["video_title"] = title
            all_comments.append(df_comments)
        except Exception as e:
            print(f"⚠️ 無法處理影片 {vid}：{e}")

    # 合併並儲存
    all_df = pd.concat(all_comments, ignore_index=True)
    all_df.to_csv(output_path, index=False, encoding="utf-8-sig")
    print(f"✅ 所有留言已儲存至 {output_path}")

# 執行
if __name__ == "__main__":
    playlist_id = "PLoXw5hFmURCQOx8SZRrLhZUj8s3FOUWgZ"
    scrape_jay_playlist(playlist_id)
# Out:
# 📥 抓取播放清單影片中...
# ✅ 共找到 165 部影片
# 🎬 處理中：周杰倫 Jay Chou【可愛女人 Cute Girl (feat.徐若瑄Vivian)】 -Official Music Video (87VUC4J_0Ps)
# 🎬 處理中：周杰倫 Jay Chou【完美主義 Perfectionism】-Official Music Video (gxZHH8x2zPg)
# 🎬 處理中：周杰倫 Jay Chou【星晴 Starry Mood】-Official Music Video (sTNJsIcPSvE)
# 🎬 處理中：周杰倫 Jay Chou【娘子 Wife】-Official Music Video (MpP9dw_j2PI)
# 🎬 處理中：周杰倫 Jay Chou【鬥牛 Basketball Match】-Official Music Video (npiAxeLtHDM)
# 🎬 處理中：周杰倫 Jay Chou【黑色幽默 Dark Humor】-Official Music Video (wRT-5heURhY)
# 🎬 處理中：周杰倫Jay Chou【伊斯坦堡 Istanbul】-Official Music Video (s9wvjSkR_Ms)
# 🎬 處理中：周杰倫 Jay Chou【印地安老斑鳩 Ancient Indian Turtledove】-Official Music Video (hnmWCmR6o7A)
# 🎬 處理中：周杰倫 Jay Chou【龍捲風 Tornado】-Official Music Video (RPWDeLqsN0g)
# 🎬 處理中：Jay Chou 周杰倫【反方向的鐘 Counter-clockwise Clock】-Official Music Video (fuM1aVCGR8c)
# 🎬 處理中：周杰倫 Jay Chou【愛在西元前 Love before AD】Official MV (5XK2C9w6oVk)
# 🎬 處理中：周杰倫 Jay Chou【爸 我回來了 Dad, I'm home】Official MV (nhyT8HDT4lg)
# 🎬 處理中：周杰倫 Jay Chou【簡單愛 Simple Love】Official MV (Y4xCVlyCvX4)
# 🎬 處理中：周杰倫 Jay Chou【忍者 Ninja】Official MV (55yJh4SHUBY)
# 🎬 處理中：周杰倫 Jay Chou【開不了口 I Find It Hard To Say】Official MV (H7hpK6cm-6k)
# 🎬 處理中：周杰倫 Jay Chou【上海 一九四三 Shanghai 1943】Official MV (CcfnZOJpbM4)
# 🎬 處理中：周杰倫 Jay Chou【對不起 Sorry】Official MV (N2DkKFxijv0)
# 🎬 處理中：周杰倫 Jay Chou【威廉古堡 William Castle】Official MV (lCzWCxVAkfc)
# 🎬 處理中：周杰倫 Jay Chou【雙截棍 Nunchucks】Official MV (OR-0wptI_u0)
# 🎬 處理中：周杰倫 Jay Chou【安靜 Silence】Official MV (1hI-7vj2FhE)
# 🎬 處理中：周杰倫 Jay Chou【蝸牛 Snail】Official MV (H7pOrQEnc3c)
# 🎬 處理中：周杰倫 Jay Chou【你比從前快樂 You Are Happier Than Before】Official MV (X_XqvQJi_6E)
# 🎬 處理中：周杰倫 Jay Chou【世界末日 End of the World】Official MV (NDFULbHgL6E)
# 🎬 處理中：周杰倫 Jay Chou【半獸人 Half-beast Human】Official MV (3I27c6t-0No)
# 🎬 處理中：周杰倫 Jay Chou【半島鐵盒 Peninsula Ironbox】Official MV (duZDsG3tvoA)
# 🎬 處理中：周杰倫 Jay Chou【暗號 Secret Code】Official MV (CYT9DPJdtS4)
# 🎬 處理中：周杰倫 Jay Chou【龍拳 Dragon Fist】Official MV (_byK6M95hTc)
# 🎬 處理中：周杰倫 Jay Chou【火車叨位去 The Train's Destination】Official MV (K5qKpFLWaoA)
# 🎬 處理中：周杰倫 Jay Chou【分裂 Split】Official MV (eM6mF4RWhe0)
# 🎬 處理中：周杰倫 Jay Chou【爺爺泡的茶 Grandpa's Tea】Official MV (LdPjnubLRN0)
# 🎬 處理中：周杰倫 Jay Chou【回到過去 Back to the Past】Official MV (MKNrnSsIwf8)
# 🎬 處理中：周杰倫 Jay Chou【米蘭小鐵匠 Little Blacksmith in Milan】Official MV (KmaqqnLGUG0)
# 🎬 處理中：周杰倫 Jay Chou【最後的戰役 The Final Battle】Official MV (ZcShYmOhHM0)
# 🎬 處理中：周杰倫 Jay Chou【以父之名 In The Name of The Father】-Official Music Video (9q7JOQfcJQM)
# 🎬 處理中：周杰倫 Jay Chou【懦夫 Coward】-Official Music Video (Xi_RBDWZaT0)
# 🎬 處理中：周杰倫 Jay Chou【晴天 Sunny Day】-Official Music Video (DYptgVvkVLQ)
# 🎬 處理中：周杰倫 Jay Chou【三年二班 Class 3-2】-Official Music Video (_trE3M24kQY)
# 🎬 處理中：周杰倫 Jay Chou【東風破 Dong-Feng-Po】-Official Music Video (qct0JLjaHDc)
# 🎬 處理中：周杰倫 Jay Chou【妳聽得到 You Hear Me】-Official Music Video (kLY11fv7fUk)
# 🎬 處理中：周杰倫 Jay Chou【同一種調調 Same Tone】 -Official Music Video (D0x09XJgyO4)
# 🎬 處理中：周杰倫 Jay Chou【她的睫毛 Her Eyelashes】-Official Music Video (gqzlB7Gla2E)
# 🎬 處理中：周杰倫 Jay Chou【愛情懸崖 Cliff】-Official Music Video (H5VQdhYh9rc)
# 🎬 處理中：周杰倫 Jay Chou【梯田 Terrace Field】-Official Music Video (u9J99gB5psc)
# 🎬 處理中：周杰倫 Jay Chou 【雙刀 Double Blade】-Official Music Video (T4qPsRLjGCY)
# 🎬 處理中：周杰倫 Jay Chou【我的地盤 My Territory】-Official Music Video (RJerfq6MqY0)
# 🎬 處理中：周杰倫 Jay Chou【七里香 Orange Jasmine】-Official Music Video (Bbp9ZaJD_eA)
# 🎬 處理中：周杰倫 Jay Chou【藉口 Excuse】-Official Music Video (KcK8WurGpEQ)
# 🎬 處理中：周杰倫 Jay Chou【外婆 Grandma】-Official Music Video (Ur-x4pZT1Rk)
# 🎬 處理中：周杰倫 Jay Chou【將軍 General】-Official Music Video (PaJdceSx4JA)
# 🎬 處理中：周杰倫 Jay Chou【擱淺 Step Aside】-Official Music Video (YJfHuATJYsQ)
# 🎬 處理中：周杰倫 Jay Chou【亂舞春秋 Chaotic Dance】-Official Music Video (2Tg3uzSAkXk)
# 🎬 處理中：周杰倫 Jay Chou【困獸之鬥 Struggle】-Official Music Video (pm91leB_P8c)
# 🎬 處理中：周杰倫 Jay Chou【園遊會 Fun Fair】-Official Music Video (IoCoIxkGkVw)
# 🎬 處理中：周杰倫 Jay Chou【止戰之殤 Wounds of War】-Official Music Video (qIZ5MAwbeCg)
# 🎬 處理中：周杰倫 Jay Chou【夜曲 Nocturne】-Official Music Video (6Q0Pd53mojY)
# 🎬 處理中：周杰倫 Jay Chou【藍色風暴 Blue Storm】-Official Music Video (P7ItYKdY0WU)
# 🎬 處理中：周杰倫 Jay Chou【髮如雪 Hair White as Snow】-Official Music Video (aaM7qG2ycjk)
# 🎬 處理中：周杰倫 Jay Chou【黑色毛衣 Black Sweater】-Official Music Video (bX33UI9ZPLk)
# 🎬 處理中：周杰倫 Jay Chou【四面楚歌 Surrounded】-Official Music Video (JljURsMOLmc)
# 🎬 處理中：周杰倫 Jay Chou【楓Maple Leaf 】-Official Music Video (qzwsQTY-99o)
# 🎬 處理中：周杰倫 Jay Chou【浪漫手機 Romantic Cellphone】-Official Music Video (Kbvu9Vt5_eE)
# 🎬 處理中：周杰倫 Jay Chou【逆鱗 Against】-Official Music Video (jD0c4QY7L8s)
# 🎬 處理中：周杰倫 Jay Chou【麥芽糖 Malt Candy】-Official Music Video (Hq47d-ouX_Y)
# 🎬 處理中：周杰倫 Jay Chou【珊瑚海 Coral Sea (feat. 梁心頤 Lara)】-Official Music Video (kYhh1PpsOg4)
# 🎬 處理中：周杰倫 Jay Chou【飄移 Drift】(頭文字Dの実写版)-Official Music Video (X2njc8is50o)
# 🎬 處理中：周杰倫 Jay Chou【一路向北 All the Way North】-Official Music Video (L229QDxDakU)
# 🎬 處理中：周杰倫 Jay Chou【夜的第七章 Chapter Seven】-Official Music Video (AdkkF6MT0R0)
# 🎬 處理中：周杰倫 Jay Chou【聽媽媽的話 Listen to Mom】-Official Music Video (_B8RaLCNUZw)
# 🎬 處理中：周杰倫 Jay Chou【千里之外 Far Away (feat.費玉清 Fei Yu-ching)】-Official Music Video (ocDo3ySyHSI)
# 🎬 處理中：周杰倫 Jay Chou【本草綱目Chinese Herbal Manual】-Official Music Video (8CD06hC1KGU)
# 🎬 處理中：周杰倫 Jay Chou【退後 A Step Back】-Official Music Video (0-4mm0e2h44)
# 🎬 處理中：周杰倫 Jay Chou【紅模仿 Moulin Rouge】-Official Music Video (LL50Fu4UvG0)
# 🎬 處理中：周杰倫 Jay Chou【心雨 Rainy Mood】-Official Music Video (xVTI5eSzwzQ)
# 🎬 處理中：周杰倫 Jay Chou【白色風車 White Windmill】-Official Music Video (K9CbHZLXPIA)
# 🎬 處理中：周杰倫 Jay Chou【迷迭香 Rosemary】-Official Music Video (K0Myfz5phlY)
# 🎬 處理中：周杰倫 Jay Chou【菊花台 Chrysanthemum Terrace】-Official Music Video (PdjbRvvJAzg)
# 🎬 處理中：周杰倫 Jay Chou【牛仔很忙 Cowboy on the Run】-Official Music Video (9o20U91aJdg)
# 🎬 處理中：周杰倫 Jay Chou【彩虹 Rainbow】-Official Music Video (WxZvXPTBC0A)
# 🎬 處理中：周杰倫 Jay Chou【青花瓷 Blue and White Porcelain】-Official Music Video (Z8Mqw0b9ADs)
# 🎬 處理中：周杰倫 Jay Chou【陽光宅男 Sunshine Nerd】-Official Music Video (qQ7g1tfEGFc)
# 🎬 處理中：周杰倫 Jay Chou【蒲公英的約定 A Dandelion's Promise】-Official Music Video (VitJnr3IySc)
# 🎬 處理中：周杰倫 Jay Chou【無雙 Incomparable】-Official Music Video (IYiIL2ZgOK4)
# 🎬 處理中：周杰倫 Jay Chou【我不配 Not Good Enough For You】-Official Music Video (s-VFpsrbWLk)
# 🎬 處理中：周杰倫 Jay Chou【扯 Pull Apart】-Official Music Video (f5hakuX3lCA)
# 🎬 處理中：周杰倫 Jay Chou【甜甜的 Sweet】-Official Music Video (mm8T-lBXQXA)
# 🎬 處理中：周杰倫 Jay Chou【最長的電影 The Longest Movie】-Official Music Video (2zxc27bvrO8)
# 🎬 處理中：周杰倫 Jay Chou【龍戰騎士 Dragon Rider】-Official Music Video (6VRioN8euIs)
# 🎬 處理中：周杰倫 Jay Chou【給我一首歌的時間 Give me the Time of One Song】-Official Music Video (wt0RKW3aC84)
# 🎬 處理中：周杰倫 Jay Chou【蛇舞 Snake Dance】-Official Music Video (aO9SU-w8hnM)
# 🎬 處理中：周杰倫 Jay Chou【花海 Floral Sea】-Official Music Video (q1ww6bDjfiI)
# 🎬 處理中：周杰倫 Jay Chou【魔術先生Magician】-Official Music Video (UXwHuKmuhW8)
# 🎬 處理中：周杰倫 Jay Chou【說好的幸福呢 The Promised Love】-Official Music Video (mLFhTFiX0uM)
# 🎬 處理中：周杰倫 Jay Chou【蘭亭序 Lan-Ting-Xu】-Official Music Video (s5Xl5MXboas)
# 🎬 處理中：周杰倫 Jay Chou【流浪詩人 Drifting Poet】-Official Music Video (-ytYpXm3cv0)
# 🎬 處理中：周杰倫 Jay Chou【時光機 Time Machine】-Official Music Video (nCfrfCzaB2A)
# 🎬 處理中：周杰倫 Jay Chou【喬克叔叔 Uncle Joker】-Official Music Video (GKT_1DTa2as)
# 🎬 處理中：周杰倫 Jay Chou【稻香 Rice Field】-Official Music Video (sHD_z90ZKV0)
# 🎬 處理中：周杰倫 Jay Chou【跨時代 The Era】Official MV (-WkecBaA4z8)
# 🎬 處理中：周杰倫 Jay Chou【說了再見 Say Goodbye】Official MV (KKsioz-zaZY)
# 🎬 處理中：周杰倫 Jay Chou【煙花易冷 Fade Away】Official MV (COMHDRqAvYE)
# 🎬 處理中：周杰倫 Jay Chou【免費教學錄影帶 Free Tutorial Video】Official MV (lqVvHAFPIrw)
# 🎬 處理中：周杰倫 Jay Chou【好久不見 Long Time No See】Official MV (uAUBexRRFr0)
# 🎬 處理中：周杰倫 Jay Chou【雨下一整晚 Rain All Night】Official MV (jOxzAsnx9-0)
# 🎬 處理中：周杰倫 Jay Chou【嘻哈空姐 Hip-hop Flight Attendant】Official MV (I1boAt2ChIs)
# 🎬 處理中：周杰倫 Jay Chou【我落淚 情緒零碎 Tears of Scattered Emotion】Official MV (6d0v2InyN_w)
# 🎬 處理中：周杰倫 Jay Chou【愛的飛行日記 Diary of Love (feat. 楊瑞代 Gary)】Official MV (odNYK272RtQ)
# 🎬 處理中：周杰倫 Jay Chou【自導自演 Self-directed Act】Official MV (pbyWurQZ948)
# 🎬 處理中：周杰倫 Jay Chou【超人不會飛 Superman Can't Fly】Official MV (4j0Fgmsxr-o)
# 🎬 處理中：周杰倫 Jay Chou【驚嘆號 Exclamation Point】Official MV (JNS-KT_iwmg)
# 🎬 處理中：周杰倫 Jay Chou【迷魂曲 Enchanting Melody】Official MV (rFxBQWh7ZOQ)
# 🎬 處理中：周杰倫 Jay Chou【Mine Mine】Official MV (me7jfhFIZvk)
# 🎬 處理中：周杰倫 Jay Chou【公主病 Princess Syndrome】Official MV (S-p4gXbIifo)
# 🎬 處理中：周杰倫 Jay Chou【你好嗎 How Are You】Official MV (Wrbjahfg8RM)
# 🎬 處理中：周杰倫 Jay Chou【療傷燒肉粽 Healing Rice Dumpling】Official MV (Aa5j0_61Xfo)
# 🎬 處理中：周杰倫 Jay Chou【琴傷 Piano of Sorrow】Official MV (yHoadRoVF-U)
# 🎬 處理中：周杰倫 Jay Chou【水手怕水 Sailor Afraid of Water】Official MV (wUJ37I6au2w)
# 🎬 處理中：周杰倫 Jay Chou【世界未末日 Not the End of the World】Official MV (IteE-HMVJ1M)
# 🎬 處理中：周杰倫 Jay Chou【皮影戲 Shadow Play】Official MV (qeW7xypeu6o)
# 🎬 處理中：周杰倫 Jay Chou【超跑女神 Sports Car Model】Official MV (CllkiAZajJI)
# 🎬 處理中：周杰倫 Jay Chou【四季列車 Four Seasons Train】Official MV (SnKAHq6O0Is)
# 🎬 處理中：Jay Chou 周杰倫【手語 Sign Language】-Official Music Video (ChXiROKng30)
# 🎬 處理中：周杰倫 Jay Chou【公公偏頭痛 Eunuch with a Headache】Official MV (FbqBv7Tz1QY)
# 🎬 處理中：周杰倫 Jay Chou【明明就 Ming Ming Jiu】Official MV (UBySINroNkw)
# 🎬 處理中：周杰倫 Jay Chou【傻笑 Smile (feat. 袁詠琳 Cindy)】Official MV (rKFtivD7Rvw)
# 🎬 處理中：周杰倫 Jay Chou【比較大的大提琴 A Larger Cello】Official MV (P_XikgjUOS0)
# 🎬 處理中：周杰倫 Jay Chou【愛你沒差 Love you, no matter what】Official MV (miBGaUagOz8)
# 🎬 處理中：周杰倫 Jay Chou【紅塵客棧 Hong-Chen Inn】Official MV (L6joGUdc6y4)
# 🎬 處理中：周杰倫 Jay Chou【夢想啟動 Dream】Official MV (b42KZYgxXZ0)
# 🎬 處理中：周杰倫 Jay Chou【大笨鐘 Big Ben】Official MV (-u4sPnpaFEA)
# 🎬 處理中：周杰倫 Jay Chou【哪裡都是你 You are everywhere】Official MV (yfn8sE9obWU)
# 🎬 處理中：周杰倫 Jay Chou【烏克麗麗 Ukulele】Official MV (-QqpEvN2Xd8)
# 🎬 處理中：周杰倫 Jay Chou【陽明山 Yang-Ming Mountain】Official MV (ft. Henry Link) (BZlFlBnwfOQ)
# 🎬 處理中：周杰倫 Jay Chou【竊愛 Stolen Love】Official MV (6ZeE3vgwQSI)
# 🎬 處理中：周杰倫 Jay Chou【算什麼男人 What Kind of Man】Official MV (ft. 林依晨) (v489sYYjtHI)
# 🎬 處理中：周杰倫 Jay Chou【天涯過客 Passer-by】Official MV (-gJzlOJ0Zoo)
# 🎬 處理中：周杰倫 Jay Chou【怎麼了 What's Wrong (feat. 袁詠琳 Cindy)】Official MV (RcdscWaat_w)
# 🎬 處理中：周杰倫 Jay Chou【一口氣全唸對 One Breath】Official MV (C18nyaRnR1Q)
# 🎬 處理中：周杰倫 Jay Chou【我要夏天 I Want Summer (feat. 楊瑞代 Gary)】Official MV (3LFDEeLm0ss)
# 🎬 處理中：周杰倫 Jay Chou【手寫的從前 Handwritten Past】Official MV (TMB6-YflpA4)
# 🎬 處理中：周杰倫 Jay Chou【鞋子特大號 Extra Large Shoes】Official MV (syYc5dydzmE)
# 🎬 處理中：周杰倫 Jay Chou【聽爸爸的話 Listen to Dad】Official MV (eS2T9IiOYbc)
# 🎬 處理中：周杰倫 Jay Chou【美人魚 Mermaid】Official MV (nHtW9w12uYc)
# 🎬 處理中：周杰倫 Jay Chou【聽見下雨的聲音 Rhythm of the Rain】Official MV (zqKoXPHhmsM)
# 🎬 處理中：周杰倫 Jay Chou【床邊故事 Bedtime Stories】Official MV (-7r6VqSllNg)
# 🎬 處理中：周杰倫 Jay Chou【 說走就走 Let's Go】Official MV (NH43WjeoVgs)
# 🎬 處理中：周杰倫 Jay Chou【一點點 A Little Bit】Official MV (COhiu3c7Sgc)
# 🎬 處理中：周杰倫 Jay Chou【前世情人 Lover From Previous Life】Official MV (j9k3liT2MLo)
# 🎬 處理中：周杰倫 - 英雄（2017英雄聯盟世界大賽 混音版）Jay Chou - Hero (Worlds Remix) | Worlds 2017 - League of Legends (Xo1RPOrOvK4)
# 🎬 處理中：周杰倫Jay Chou X aMEI【不該 Shouldn't Be】Official MV (_VxLOj3TB5k)
# 🎬 處理中：周杰倫 Jay Chou (feat. 林書豪Jeremy Lin)【土耳其冰淇淋 Tu Er Qi Ice Cream】Official MV (kOriLqPD7PI)
# 🎬 處理中：周杰倫 Jay Chou (特別演出: 派偉俊)【告白氣球 Love Confession】Official MV (bu7nU9Mhpyo)
# 🎬 處理中：周杰倫 Jay Chou 【Now You See Me】Official MV (120s) (LbUKhXO2oCs)
# 🎬 處理中：周杰倫 Jay Chou【愛情廢柴 Failure at love】Official MV (2kdYSeoHChg)
# 🎬 處理中：周杰倫 Jay Chou【等你下課 Waiting For You  (with 楊瑞代 Gary)】歌詞版Lyrics MV (kfXdP7nZIiE)
# 🎬 處理中：周杰倫 Jay Chou【不愛我就拉倒 If You Don't Love Me, It's Fine】Official MV 發燒影片華語地區蟬聯第一 美國直衝前二 (MAjY8mCTXWk)
# 🎬 處理中：Deleted video (YsriKxbuRzk)
# ⚠️ 無法處理影片 YsriKxbuRzk：<HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=YsriKxbuRzk&maxResults=100&textFormat=plainText&key=AIzaSyARxdC_4SvFPyiilr-DCMvi_SyQfB3C1xE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter could not be found.', 'domain': 'youtube.commentThread', 'reason': 'videoNotFound', 'location': 'videoId', 'locationType': 'parameter'}]">
# 🎬 處理中：周杰倫 - 軌跡 HD (7O2ak5803mI)
# 🎬 處理中：周杰倫 Jay Chou【霍元甲 Fearless】-Official Music Video (wr-6wwt8RXk)
# 🎬 處理中：周杰倫 Jay Chou【獻世 官方完整MV】concert in Hong Kong (bW-6EF6Ayoo)
# 🎬 處理中：周杰倫 Jay Chou【黃金甲 Golden Armor】-Official Music Video (DuErkkiCaZU)
# 🎬 處理中：周杰倫 Jay Chou【不能說的祕密 Secret】-Official Music Video (uIWypArI73w)
# 🎬 處理中：Jay Chou 周杰倫【天地一鬥 Spark 】-Official Music Video(ft. Kobe Bryant) (eaW0jUGaHe0)
# 🎬 處理中：Jay Chou 周杰倫【周大俠 Master Chou】-Official Music Video(電影「功夫灌籃」主題曲) (EZxhW-uSN_I)
# 🎬 處理中：周杰倫 Jay Chou【天台的月光 Moonlight on the Rooftop】Official Music Video (GDBD6h8BWIc)
# 🎬 處理中：團練系列｜隊友不相信我的妮可？讓我用操作證明！【西門夜說westdoor】 (JE9TgpgMQTI)
# ✅ 所有留言已儲存至 jay_playlist_comments.csv
